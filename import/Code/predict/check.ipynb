# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
obt=pd.read_csv(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\import\Code\predict\2023_predictions.csv')

giv=pd.read_csv(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\import\dataset\combined_set.csv')





obt
# Out:
#            Date  Predicted QTY.(KGS)
# 0    2023-01-01           1092330.50
# 1    2023-01-02           1087884.00
# 2    2023-01-03           1083532.60
# 3    2023-01-04           1079276.20
# 4    2023-01-05           1075114.80
# ..          ...                  ...
# 360  2023-12-27            952763.10
# 361  2023-12-28            951999.25
# 362  2023-12-29            951305.94
# 363  2023-12-30            950682.40
# 364  2023-12-31            950128.00
#
# [365 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(15,8))
plt.plot(giv['Sail Date.'], giv['QTY.(KGS)'])
plt.xlabel('Sail Date.')
plt.ylabel('QTY.(KGS)')
plt.title('QTY.(KGS) vs Sail Date.')
plt.xlim(giv['Sail Date.'].min(), giv['Sail Date.'].max())
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your dataset is in a CSV file named 'dataset.csv'


# Plotting histogram
plt.figure(figsize=(10, 6))
plt.hist(giv['QTY.(KGS)'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Predicted Quantities')
plt.xlabel('Predicted Quantity (KGS)')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(15,8))
plt.plot(obt['Date'], obt['Predicted QTY.(KGS)'])
plt.xlabel('Date')
plt.ylabel('Predicted QTY.(KGS)')
plt.title('Predicted QTY.(KGS) vs Date')


plt.xlim(obt['Date'].min(), obt['Date'].max())
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'obt' is your DataFrame containing the dataset

plt.figure(figsize=(15, 8))
plt.plot(obt['Date'], obt['Predicted QTY.(KGS)'])
plt.xlabel('Date')
plt.ylabel('Predicted QTY.(KGS)')
plt.title('Predicted QTY.(KGS) vs Date')


plt.xlim(obt['Date'].min(), obt['Date'].max())

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'obt' is your DataFrame containing the dataset

plt.figure(figsize=(15, 8))
plt.plot(obt['Date'], obt['Predicted QTY.(KGS)'])
plt.xlabel('Date')
plt.ylabel('QTY.(KGS)')
plt.title('LSTM QTY.(KGS) vs Date')

plt.xlim(obt['Date'].min(), obt['Date'].max())
plt.ylim(0, 1597752.56)  
plt.show()
