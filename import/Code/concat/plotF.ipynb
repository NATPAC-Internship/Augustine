# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\import\Code\concat\final.csv')
df
# Out:
#     Month_Day       2023       2024       2025       2026       2027
# 0       01-01   337485.0   686993.0  1284272.0  1244317.0  1285112.0
# 1       01-02  1030556.0  1920106.0   985410.0  1499299.0   805926.0
# 2       01-03  1030556.0  1598395.0   985410.0  1115398.0  1198180.0
# 3       01-04   697207.0  1621244.0   110652.0   213313.0  2054215.0
# 4       01-05  1464201.0   148152.0   985410.0  1020265.0  1198180.0
# ..        ...        ...        ...        ...        ...        ...
# 360     12-27   125924.0   643626.0   985410.0  2648166.0  1669346.0
# 361     12-28  2477337.0   995967.0  3430383.0  1001102.0  1113987.0
# 362     12-29  1030556.0   392141.0   985410.0   966369.0   278274.0
# 363     12-30  1030556.0  1054901.0   134188.0   178873.0   416466.0
# 364     12-31   903441.0  1088381.0   985410.0  1001102.0  1218553.0
#
# [365 rows x 6 columns]

# %%
df = df.drop(columns=['2024','2025','2026',	'2027' ])

# %%
df
# Out:
#     Month_Day       2023
# 0       01-01   337485.0
# 1       01-02  1030556.0
# 2       01-03  1030556.0
# 3       01-04   697207.0
# 4       01-05  1464201.0
# ..        ...        ...
# 360     12-27   125924.0
# 361     12-28  2477337.0
# 362     12-29  1030556.0
# 363     12-30  1030556.0
# 364     12-31   903441.0
#
# [365 rows x 2 columns]

# %%
df.to_csv(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\import\Code\concat\prediction.csv', index=False)

# %%
plt.figure(figsize=(15,8))
plt.plot(df['Month_Day'], df['2023'])
plt.xlabel('Month_Day')
plt.ylabel('2023 quantityes')
plt.title('REGRESSION - 2023(Quantityes) vs Month_Day')
plt.xlim(df['Month_Day'].min(), df['Month_Day'].max())
plt.show()

# %%
max_value = df['2023'].max()

print("Maximum value in '2023':", max_value)

min_value = df['2023'].min()

print("Minimum value in '2023':", min_value)

ghh= max_value - min_value
print(ghh," is the difference")
# Out:
# Maximum value in '2023': 3598010.999999998
# Minimum value in '2023': 4835.000000000815
# 3593175.999999997  is the difference
