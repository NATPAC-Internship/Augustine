# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\augus\AppData\Local\Temp\ipykernel_8904\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_2015 = pd.read_excel(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\RawDataSet\EXP 2015.xlsx')
df_2016 = pd.read_excel(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\RawDataSet\EXP 2016.xlsx')
df_2017 = pd.read_excel(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\RawDataSet\EXP 2017.xlsx')
df_2018 = pd.read_excel(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\RawDataSet\EXP 2018.xlsx')
df_2019 = pd.read_excel(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\RawDataSet\EXP 2019.xlsx')
df_2020 = pd.read_excel(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\RawDataSet\EXP 2020.xlsx')
df_2021 = pd.read_excel(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\RawDataSet\EXP 2021.xlsx')
df_2022 = pd.read_excel(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\RawDataSet\EXP 2022.xlsx')
df_2023 = pd.read_excel(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\RawDataSet\EXP 2023.xlsx')

# %%
df_2015
# Out:
#         COCHIN CHAMBER OF COMMERCE AND INDUSTRY  \
# 0                     CONTAINER MOVEMENT-EXPORT
# 1           01-JANUARY-2015 TO 31-DECEMBER-2015
# 2                     CIN U91110KL1938NPL001413
# 3                                      Exporter
# 4                 2M INDUSTRIAL ENTERPRISES LLP
# ...                                         ...
# 64752                            ZUHANA EXPORTS
# 64753                            ZUHANA EXPORTS
# 64754                            ZUHANA EXPORTS
# 64755  TOTAL
# 64756  GRAND TOTAL
#
#                            Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0                                 NaN         NaN         NaN
# 1                                 NaN         NaN         NaN
# 2                                 NaN         NaN         NaN
# 3                             Product  Sail Date.   QTY.(KGS)
# 4                              SPARES  22-08-2015       10260
# ...                               ...         ...         ...
# ...

# %%
import pandas as pd

# Assuming df_2015 to df_2023 are your DataFrames
# You can adjust the names according to your actual DataFrame names

# List of your DataFrames
dfs = [df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022, df_2023]

# Remove first four rows from each DataFrame
for df in dfs:
    df.drop(range(4), inplace=True)

# Now, df_2015 to df_2023 have their first four rows removed

# %%
dfs
# Out:
# [        COCHIN CHAMBER OF COMMERCE AND INDUSTRY  \
#  4                 2M INDUSTRIAL ENTERPRISES LLP
#  5      TOTAL
#  6                                  5P HORTIPLEX
#  7      TOTAL
#  8                                A & B TOOLLERS
#  ...                                         ...
#  64752                            ZUHANA EXPORTS
#  64753                            ZUHANA EXPORTS
#  64754                            ZUHANA EXPORTS
#  64755  TOTAL
#  64756  GRAND TOTAL
#
#                             Unnamed: 1  Unnamed: 2  Unnamed: 3
#  4                              SPARES  22-08-2015       10260
#  5                                                       10260
#  6                         LIVE PLANTS  09-09-2015       20000
#  7                                                       20000
#  8                         MACHINERIES  18-12-2015        2360
#  ...                               ...         ...         ...
# ...

# %%
for df in dfs:
    df.drop(df.columns[1:], axis=1, inplace=True)

# %%
dfs
# Out:
# [        COCHIN CHAMBER OF COMMERCE AND INDUSTRY
#  4                 2M INDUSTRIAL ENTERPRISES LLP
#  5      TOTAL
#  6                                  5P HORTIPLEX
#  7      TOTAL
#  8                                A & B TOOLLERS
#  ...                                         ...
#  64752                            ZUHANA EXPORTS
#  64753                            ZUHANA EXPORTS
#  64754                            ZUHANA EXPORTS
#  64755  TOTAL
#  64756  GRAND TOTAL
#
#  [64753 rows x 1 columns],
#          COCHIN CHAMBER OF COMMERCE AND INDUSTRY
#  4              2F WIND POWER COIMBATORE PVT LTD
#  5              2F WIND POWER COIMBATORE PVT LTD
#  6      TOTAL
#  7                 2M INDUSTRIAL ENTERPRISES LLP
#  8                 2M INDUSTRIAL ENTERPRISES LLP
#  ...                                         ...
#  66941                            ZUHANA EXPORTS
#  66942                            ZUHANA EXPORTS
#  66943                            ZUHANA EXPORTS
#  66944  TOTAL
# ...

# %%
result = pd.concat(dfs, axis=0)

# Save the result as a new CSV file
result.to_csv('join.csv', index=False)

# %%
df_jo=pd.read_csv(r"C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Code\Clean\join.csv")

# %%
df_jo
# Out:
#          COCHIN CHAMBER OF COMMERCE AND INDUSTRY
# 0                  2M INDUSTRIAL ENTERPRISES LLP
# 1       TOTAL
# 2                                   5P HORTIPLEX
# 3       TOTAL
# 4                                 A & B TOOLLERS
# ...                                          ...
# 556125                     ZYGON IMPORTS&EXPORTS
# 556126  TOTAL
# 556127                              ZYLO EXPORTS
# 556128  TOTAL
# 556129  GRAND TOTAL
#
# [556130 rows x 1 columns]

# %%
# Assuming df_jo is your DataFrame
# You can adjust the name according to your actual DataFrame name

# Remove rows containing "TOTAL" and "GRAND TOTAL" in the "name" column
df_jo = df_jo[~df_jo['COCHIN CHAMBER OF COMMERCE AND INDUSTRY'].str.contains('TOTAL|GRAND TOTAL', case=False)]

# Now, df_jo doesn't contain rows with "TOTAL" or "GRAND TOTAL" in the "name" column

# %%
df_jo
# Out:
#        COCHIN CHAMBER OF COMMERCE AND INDUSTRY
# 0                2M INDUSTRIAL ENTERPRISES LLP
# 2                                 5P HORTIPLEX
# 4                               A & B TOOLLERS
# 5                               A & B TOOLLERS
# 7                                A HANDICRAFTS
# ...                                        ...
# 556121                      ZUVA INTERNATIONAL
# 556123                   ZYGON IMPORTS&EXPORTS
# 556124                   ZYGON IMPORTS&EXPORTS
# 556125                   ZYGON IMPORTS&EXPORTS
# 556127                            ZYLO EXPORTS
#
# [520271 rows x 1 columns]

# %%
df_jo = df_jo.drop_duplicates(subset="COCHIN CHAMBER OF COMMERCE AND INDUSTRY")

df_jo = df_jo.dropna()

# %%
df_jo
# Out:
#        COCHIN CHAMBER OF COMMERCE AND INDUSTRY
# 0                2M INDUSTRIAL ENTERPRISES LLP
# 2                                 5P HORTIPLEX
# 4                               A & B TOOLLERS
# 7                                A HANDICRAFTS
# 10                              A ONE BUSINESS
# ...                                        ...
# 555987                          ZEN PACK INDIA
# 555996                            ZF WINDPOWER
# 556115                 ZJM EXPORTS AND IMPORTS
# 556117                            ZULI EXPORTS
# 556127                            ZYLO EXPORTS
#
# [13556 rows x 1 columns]

# %%
df_jo.to_csv('join.csv', index=False)
