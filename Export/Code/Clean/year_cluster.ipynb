# %%
import pandas as pd
import numpy as nb

# %%
df=pd.read_csv(r"C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\filtered_clustered_clster2.csv")

# %%
df
# Out:
#                        Exporter Name  \
# 0                       5P HORTIPLEX
# 1                           A.A.NUTS
# 2      A.K. AHAMED MODERAN RICE MILL
# 3                    A.K.R. TEXTILES
# 4                      A.M.FISHERIES
# ...                              ...
# 2640  WAYANAD ORGANIC RESEARCH P LTD
# 2641           WAYANAD SPICE VILLAGE
# 2642               YUGA DEMETER EXIM
# 2643                        ZAIN TEX
# 2644                    ZULI EXPORTS
#
#                                                 Address       State     pin  \
# 0     19, 2nd St, Balamurugan Nagar, Anna Nagar Exte...  Tamil Nadu  600042
# 1     WJMW+7F7, Chandanathope, Mamoodu, Kerala 14, I...      Kerala  686012
# 2     P.O, 40/2, Mannarpalayam Main Rd, Allikuttai, ...  Tamil Nadu  636017
# 3     48W5+XQ9, Velampalayam, A.Thirumuruganpoondi, ...  Tamil Nadu  641652
# 4     98WW+WWQ, Valanjavazhy, Ambalapuzha, Kerala 68...      Kerala  688005
# ...                                                 ...         ...     ...
# 2640                             Wayanad, Kerala, India      Kerala  686012
# 2641      Surabhikavala, Pulpally, Kerala 673579, India      Kerala  673579
# 2642  4 335 2.p.a.p Canal Feeder Road Munnar, Main R...  Tamil Nadu  642112
# 2643  24, Sivanar Street, Sendarapatti, Gugai, Salem...  Tamil Nadu  636006
# 2644  near GLPS Nottappuram, C Building, 12- 281, Pu...      Kerala  676304
#
#          2015     2016     2017     2018     2019     2020     2021     2022  \
# 0       20000        0        0        0        0        0        0        0
# 1     1346288        0        0        0        0        0        0        0
# 2      214500    48600        0    24000    24000   144685   194590   452294
# 3      441797   361413   679656   568203   197687    14754        0     2841
# 4     1374800  1961480  2034720  3308895  2385049  1697278  2512818  3724210
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 2640        0        0        0        0        0        0        0        0
# 2641        0        0        0        0        0        0        0        0
# 2642        0        0        0        0        0        0        0        0
# 2643        0        0        0        0        0        0        0        0
# 2644        0        0        0        0        0        0        0        0
#
#          2023                     Taluk    District   Latitude  Longitude  \
# 0           0  Chennai City Corporation     Chennai  12.978761  80.197810
# 1           0                  Kottayam    Kottayam   9.548567  76.522308
# 2     1653150                Allikuttai       Salem  11.671925  78.192939
# 3           0                  Tiruppur  Coimbatore  11.139879  77.314291
# 4     3315054              Ambalappuzha   Alappuzha   9.407684  76.351707
# ...       ...                       ...         ...        ...        ...
# 2640      401                  Kottayam    Kottayam   9.548567  76.522308
# 2641    34707            Sulthanbathery     Wayanad  11.798784  76.174897
# 2642    28000                 Udamalpet  Coimbatore  10.507437  77.203841
# 2643     5088                     Salem       Salem  11.643417  78.152907
# 2644    28500               Tirurangadi  Malappuram  11.056520  75.983266
#
#       Cluster
# 0           2
# 1           0
# 2           1
# 3           1
# 4           0
# ...       ...
# 2640        0
# 2641        3
# 2642        1
# 2643        1
# 2644        3
#
# [2645 rows x 18 columns]

# %%
df.df(cls[2015[0]])

# %%
d_2015 = df[df['2015'] != 0]

d_2016 = df[df['2016'] != 0]

d_2017 = df[df['2017'] != 0]

d_2018 = df[df['2018'] != 0]

d_2019 = df[df['2019'] != 0]

d_2020 = df[df['2020'] != 0]

d_2021 = df[df['2021'] != 0]

d_2022 = df[df['2022'] != 0]

d_2023 = df[df['2023'] != 0]

# %%
d_2023
# Out:
#                        Exporter Name  \
# 2      A.K. AHAMED MODERAN RICE MILL
# 4                      A.M.FISHERIES
# 6                     A.N.P.APPARELS
# 8                      A.P.ENGINEERS
# 10                       A.S.M.KNITS
# ...                              ...
# 2640  WAYANAD ORGANIC RESEARCH P LTD
# 2641           WAYANAD SPICE VILLAGE
# 2642               YUGA DEMETER EXIM
# 2643                        ZAIN TEX
# 2644                    ZULI EXPORTS
#
#                                                 Address       State     pin  \
# 2     P.O, 40/2, Mannarpalayam Main Rd, Allikuttai, ...  Tamil Nadu  636017
# 4     98WW+WWQ, Valanjavazhy, Ambalapuzha, Kerala 68...      Kerala  688005
# 6     48F6+985, MGR Nagar, Sirupooluvapatti, Tiruppu...  Tamil Nadu  641687
# 8     Ho, Sipcot Industrial Growth Centre, Plot No-C...  Tamil Nadu  638052
# 10    5, Singaravelu St, T. Nagar, Chennai, Tamil Na...  Tamil Nadu  600017
# ...                                                 ...         ...     ...
# 2640                             Wayanad, Kerala, India      Kerala  686012
# 2641      Surabhikavala, Pulpally, Kerala 673579, India      Kerala  673579
# 2642  4 335 2.p.a.p Canal Feeder Road Munnar, Main R...  Tamil Nadu  642112
# 2643  24, Sivanar Street, Sendarapatti, Gugai, Salem...  Tamil Nadu  636006
# 2644  near GLPS Nottappuram, C Building, 12- 281, Pu...      Kerala  676304
#
#          2015     2016     2017     2018     2019     2020     2021     2022  \
# 2      214500    48600        0    24000    24000   144685   194590   452294
# 4     1374800  1961480  2034720  3308895  2385049  1697278  2512818  3724210
# 6        2721     3569     4421        0        0        0    63746   124261
# 8      139924    17140    12617   197771   293091    36020   118131    18940
# 10        854     5274        0        0        0        0        0      337
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 2640        0        0        0        0        0        0        0        0
# 2641        0        0        0        0        0        0        0        0
# 2642        0        0        0        0        0        0        0        0
# 2643        0        0        0        0        0        0        0        0
# 2644        0        0        0        0        0        0        0        0
#
#          2023           Taluk    District   Latitude  Longitude  Cluster
# 2     1653150      Allikuttai       Salem  11.671925  78.192939        1
# 4     3315054    Ambalappuzha   Alappuzha   9.407684  76.351707        0
# 6       37999        Tiruppur  Coimbatore  11.098052  77.309765        1
# 8      451180           Erode       Erode  11.281184  77.589563        1
# 10       4701         Chennai     Chennai  13.042568  80.234592        2
# ...       ...             ...         ...        ...        ...      ...
# 2640      401        Kottayam    Kottayam   9.548567  76.522308        0
# 2641    34707  Sulthanbathery     Wayanad  11.798784  76.174897        3
# 2642    28000       Udamalpet  Coimbatore  10.507437  77.203841        1
# 2643     5088           Salem       Salem  11.643417  78.152907        1
# 2644    28500     Tirurangadi  Malappuram  11.056520  75.983266        3
#
# [1261 rows x 18 columns]

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = d_2015['Latitude'].mean()
mean_longitude = d_2015['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in d_2015.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']]),
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Visualisation\Cluster_Year\d_2015.html')

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = d_2016['Latitude'].mean()
mean_longitude = d_2016['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in d_2016.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']]),
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Visualisation\Cluster_Year\d_2016.html')

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = d_2017['Latitude'].mean()
mean_longitude = d_2017['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in d_2017.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']]),
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Visualisation\Cluster_Year\d_2017.html')

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = d_2018['Latitude'].mean()
mean_longitude = d_2018['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in d_2018.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']]),
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Visualisation\Cluster_Year\d_2018.html')

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = d_2019['Latitude'].mean()
mean_longitude = d_2019['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in d_2019.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']]),
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Visualisation\Cluster_Year\d_2019.html')

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = d_2020['Latitude'].mean()
mean_longitude = d_2020['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in d_2020.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']]),
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Visualisation\Cluster_Year\d_2020.html')

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = d_2021['Latitude'].mean()
mean_longitude = d_2021['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in d_2021.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']]),
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Visualisation\Cluster_Year\d_2021.html')

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = d_2022['Latitude'].mean()
mean_longitude = d_2022['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in d_2022.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']]),
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Visualisation\Cluster_Year\d_2022.html')

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = d_2023['Latitude'].mean()
mean_longitude = d_2023['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in d_2023.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']]),
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Visualisation\Cluster_Year\d_2023.html')

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = d_2015['Latitude'].mean()
mean_longitude = d_2015['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in d_2015.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']]),
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Visualisation\cl_2015.html')
